# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Images/me.jpg')

# %%
plt.imshow(img)

# %% [markdown]
# #### openCV filps the values as BGR (Instead of RGB), so our image is different

# %%
newImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(newImg)

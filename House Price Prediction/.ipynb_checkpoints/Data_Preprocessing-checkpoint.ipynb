# %% [markdown]
# # Loading Libraries and Data

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer

# plt.rcParams["figure.dpi"] = 600

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
print(train_df.shape)
train_df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
print(test_df.shape)
test_df.head()
# Out:
# (1459, 80)
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
joined_df = pd.concat([train_df.drop("SalePrice", axis=1), test_df])

print(joined_df.shape)
joined_df.head()
# Out:
# (2919, 80)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
def plot_missing(data, title="Missing values"):
    plt.figure(figsize=(28,10))
    sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap='viridis')
    plt.tick_params(labeltop=True, labelright=True)
    plt.xticks(rotation=90, fontsize=12)
    plt.title(title)
    plt.vlines(x=np.arange(0, data.shape[1]), ymin=0, ymax=data.shape[0], color='black', linestyle='--')
    plt.show()

# %%
missing_percent = (joined_df.isnull().sum().sort_values(ascending=False) / joined_df.shape[0]) * 100

print(missing_percent[:10])
features_to_drop = missing_percent.index[:6]
print(features_to_drop.values)
# Out:
# PoolQC          99.657417
# MiscFeature     96.402878
# Alley           93.216855
# Fence           80.438506
# FireplaceQu     48.646797
# LotFrontage     16.649538
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageQual       5.447071
# GarageCond       5.447071
# dtype: float64
# ['PoolQC' 'MiscFeature' 'Alley' 'Fence' 'FireplaceQu' 'LotFrontage']

# %%
joined_df = joined_df.drop(columns=features_to_drop, axis=1)

plot_missing(joined_df)

# %%
plt.figure(figsize=(28,10))
sns.heatmap(train_df.corr(), annot=True, cmap='viridis', linewidths=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Filling Missing values with reasonable data

# %%
# Utilities has only one class 1 variable. We'll remove this feature
joined_df = joined_df.drop("Utilities", axis=1)

# %%
categorical_features = []
numerical_features = []

for column in joined_df.columns:
    if(joined_df[column].dtype == 'object' and joined_df[column].isna().any()):
        categorical_features.append(column)
    elif(joined_df[column].isna().any() and joined_df[column].dtype != 'object'):
        numerical_features.append(column)

# %%
# categorical_features, numerical_features

# %%
# print(joined_df["MasVnrType"].value_counts())

# imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
# joined_df["MasVnrType"] = imputer.fit_transform(np.array(joined_df["MasVnrType"]).reshape(-1, 1))
# plot_missing(joined_df)


for column in categorical_features:
    imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
    joined_df[column] = imputer.fit_transform(np.array(joined_df[column]).reshape(-1, 1))
plot_missing(joined_df)

# %%
for column in numerical_features:
    imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
    joined_df[column] = imputer.fit_transform(np.array(joined_df[column]).reshape(-1, 1))
plot_missing(joined_df)

# %%
joined_df = pd.get_dummies(joined_df)

# %%
train_df_preprocessed = joined_df.iloc[:len(train_df)]
test_df_preprocessed = joined_df.iloc[len(train_df):]

# %% [markdown]
# ### Dealing with Outliers

# %%
train_df_preprocessed = pd.concat([train_df_preprocessed, train_df['SalePrice']], axis=1)

# %%
cols = ['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']

sns.pairplot(pd.concat([train_df_preprocessed[cols], train_df['SalePrice']], axis=1))

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(novelty=False)
preds = lof.fit_predict(np.array(train_df_preprocessed["GrLivArea"]).reshape(-1, 1))

# %%
indexes = np.where(preds==-1)

indexes[0]
# Out:
# array([  15,   29,  118,  146,  185,  241,  287,  304,  308,  523,  533,
#         587,  608,  635,  691,  769,  770,  900,  916,  960,  976, 1100,
#        1169, 1182, 1252, 1268, 1298, 1340, 1353])

# %%
sns.scatterplot(x = train_df_preprocessed['GrLivArea'], y = train_df['SalePrice'])
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
train_df_preprocessed = train_df_preprocessed.drop(labels=indexes[0], axis=0)

# %%
lof = LocalOutlierFactor(novelty=False)
preds = lof.fit_predict(np.array(train_df_preprocessed["TotalBsmtSF"]).reshape(-1, 1))

# %%
indexes = np.where(preds==-1)

indexes[0]
# Out:
# array([   0,   55,  219,  229,  323,  367,  381,  418,  431,  443,  470,
#         481,  485,  487,  492,  565,  590,  622,  695,  696,  716,  725,
#         741,  831,  835,  855,  874,  881,  952,  970,  971, 1023, 1085,
#        1112, 1177, 1233, 1311, 1323, 1344, 1371, 1382])

# %%
sns.scatterplot(x = train_df_preprocessed['TotalBsmtSF'].drop(labels=indexes[0]), y = train_df['SalePrice'])
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
train_df_preprocessed = train_df_preprocessed.drop(labels=indexes[0], axis=0)

# %%
lof = LocalOutlierFactor(novelty=False)
preds = lof.fit_predict(np.array(train_df_preprocessed["SalePrice"]).reshape(-1, 1))

indexes = np.where(preds==-1)

indexes[0]
# Out:
# array([   0,   17,   19,   27,   41,  112,  142,  172,  200,  254,  263,
#         267,  317,  331,  360,  382,  394,  407,  422,  443,  471,  502,
#         530,  547,  553,  562,  572,  590,  595,  602,  604,  658,  670,
#         675,  746,  758,  763,  772,  783,  801,  853,  919,  922,  927,
#         992,  993, 1084, 1183, 1212, 1217, 1221, 1257, 1260, 1272, 1304,
#        1311, 1362])

# %%
train_df_preprocessed = train_df_preprocessed.drop(labels=indexes[0], axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-141-b5802507734b> in <module>
# ----> 1 train_df_preprocessed = train_df_preprocessed.drop(labels=indexes[0], axis=0)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
from xgboost import XGBRegressor

model_xgb = XGBRegressor()
model_xgb.fit(train_df_preprocessed.drop("SalePrice", axis=1), train_df_preprocessed["SalePrice"])
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
from catboost import CatBoostRegressor

model_ctb = CatBoostRegressor()

model_ctb.fit(train_df_preprocessed.drop("SalePrice", axis=1), train_df_preprocessed["SalePrice"])
# Out:
# Learning rate set to 0.04313
# 0:	learn: 72622.9150520	total: 49.6ms	remaining: 49.6s
# 1:	learn: 70575.7040310	total: 51.4ms	remaining: 25.6s
# 2:	learn: 68587.1293451	total: 53.1ms	remaining: 17.7s
# 3:	learn: 66690.2114667	total: 54.7ms	remaining: 13.6s
# 4:	learn: 64880.4129398	total: 56.4ms	remaining: 11.2s
# 5:	learn: 63379.7272172	total: 58ms	remaining: 9.61s
# 6:	learn: 61671.1749050	total: 59.8ms	remaining: 8.48s
# 7:	learn: 60257.2687442	total: 61.5ms	remaining: 7.62s
# 8:	learn: 58599.1367729	total: 63.1ms	remaining: 6.95s
# 9:	learn: 57133.6401591	total: 64.7ms	remaining: 6.41s
# 10:	learn: 55597.6355572	total: 66.5ms	remaining: 5.97s
# 11:	learn: 54122.1088629	total: 68.1ms	remaining: 5.6s
# 12:	learn: 52812.8651667	total: 69.7ms	remaining: 5.29s
# 13:	learn: 51623.3689309	total: 71.4ms	remaining: 5.03s
# 14:	learn: 50467.8186637	total: 73.4ms	remaining: 4.82s
# 15:	learn: 49235.5342558	total: 75ms	remaining: 4.61s
# ...

# %%
submission = pd.read_csv('sample_submission.csv')
submission["SalePrice"] = model_ctb.predict(test_df_preprocessed)
submission.to_csv("final_submission.csv", index=False)
